# %% [markdown]
# <a href="https://colab.research.google.com/github/nicedayd/SW/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 1: Install base packages and clone esp-idf (may take a few minutes)
# !apt-get update -y
# !apt-get install -y git wget flex bison gperf python3-pip python3-setuptools build-essential cmake ninja-build
# Upgrade pip
# !pip3 install --upgrade pip
# Clone esp-idf (recursive to get submodules)
# !git clone --recursive https://github.com/espressif/esp-idf.git
# Enter the repo
# %cd /content/esp-idf
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,813 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# Cell 2: Run the esp-idf install script
# NOTE: this downloads toolchains and other components and can take 10-30+ minutes depending on speed.
# Run it in a bash cell so the interactive prompts (if any) appear in Colab. If the script asks for confirmation, accept.
# !bash ./install.sh
# After install completes, source the environment in the same cell where you run idf.py
# Out:
# INFO: Using IDF_PATH '/content/esp-idf' for installation.
# Detecting the Python interpreter
# Checking "python3" ...
# Python 3.12.12
# "python3" has been detected
# Checking Python compatibility
# Installing ESP-IDF tools
# Updating /root/.espressif/idf-env.json
# Selected targets are: esp32h2, esp32s3, esp32c6, esp32c5, esp32c61, esp32c2, esp32p4, esp32, esp32s2, esp32h21, esp32c3, esp32h4
# Current system platform: linux-amd64
# Installing tools: xtensa-esp-elf-gdb, riscv32-esp-elf-gdb, xtensa-esp-elf, riscv32-esp-elf, esp32ulp-elf, openocd-esp32, esp-rom-elfs
# Installing xtensa-esp-elf-gdb@16.3_20250913
# ...
# Destination: /root/.espressif/dist/xtensa-esp-elf-gdb-16.3_20250913-x86_64-linux-gnu.tar.gz.tmp
# Done
# Extracting /root/.espressif/dist/xtensa-esp-elf-gdb-16.3_20250913-x86_64-linux-gnu.tar.gz to /root/.espressif/tools/xtensa-esp-elf-gdb/16.3_20250913
# Installing riscv32-esp-elf-gdb@16.3_20250913
# ...
